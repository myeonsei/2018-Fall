# %% [markdown]
# # 1차 선형회귀모형 추정 후 Abnormal Return 계상
# # 그래프 - 추세 반영한 선형회귀 - coef만 있는 선형회귀

# %%
## 전체 기업 대상 0

plt.plot(caar[0])
plt.axvline(x=10.5, c='r')
plt.show()

result = stat_test(caar[0])
print(result.summary())
result = stat_test2(caar[0])
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.844
# Model:                            OLS   Adj. R-squared:                  0.827
# Method:                 Least Squares   F-statistic:                     47.05
# Date:                Fri, 02 Nov 2018   Prob (F-statistic):           1.21e-10
# Time:                        18:47:18   Log-Likelihood:                 131.44
# No. Observations:                  30   AIC:                            -254.9
# Df Residuals:                      26   BIC:                            -249.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0066      0.002      3.447      0.002       0.003       0.011
# ...

# %%
## 전체 기업 대상 1

plt.plot(caar[1])
plt.axvline(x=10.5, c='r')
plt.show()

result = stat_test(caar[1])
print(result.summary())
result = stat_test2(caar[1])
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.722
# Method:                 Least Squares   F-statistic:                     26.10
# Date:                Fri, 02 Nov 2018   Prob (F-statistic):           5.27e-08
# Time:                        18:47:18   Log-Likelihood:                 103.90
# No. Observations:                  30   AIC:                            -199.8
# Df Residuals:                      26   BIC:                            -194.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0041      0.005     -0.858      0.399      -0.014       0.006
# ...

# %%
## 전체 기업 대상 2

plt.plot(caar[2])
plt.axvline(x=10.5, c='r')
plt.show()

result = stat_test(caar[2])
print(result.summary())
result = stat_test2(caar[2])
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     128.5
# Date:                Fri, 02 Nov 2018   Prob (F-statistic):           1.04e-15
# Time:                        18:47:18   Log-Likelihood:                 113.85
# No. Observations:                  30   AIC:                            -219.7
# Df Residuals:                      26   BIC:                            -214.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0055      0.003      1.595      0.123      -0.002       0.013
# ...

# %%
## 전체 기업 대상 3

plt.plot(caar[3])
plt.axvline(x=10.5, c='r')
plt.show()

result = stat_test(caar[3])
print(result.summary())
result = stat_test2(caar[3])
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.802
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     35.06
# Date:                Fri, 02 Nov 2018   Prob (F-statistic):           2.76e-09
# Time:                        18:47:19   Log-Likelihood:                 102.80
# No. Observations:                  30   AIC:                            -197.6
# Df Residuals:                      26   BIC:                            -192.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0013      0.005     -0.265      0.793      -0.012       0.009
# ...

# %%
## 전체 기업 대상 4

plt.plot(caar[4])
plt.axvline(x=10.5, c='r')
plt.show()

result = stat_test(caar[4])
print(result.summary())
result = stat_test2(caar[4])
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.579
# Model:                            OLS   Adj. R-squared:                  0.531
# Method:                 Least Squares   F-statistic:                     11.94
# Date:                Fri, 02 Nov 2018   Prob (F-statistic):           4.21e-05
# Time:                        18:47:19   Log-Likelihood:                 110.05
# No. Observations:                  30   AIC:                            -212.1
# Df Residuals:                      26   BIC:                            -206.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0079      0.004     -2.033      0.052      -0.016    8.81e-05
# ...

# %%
## 전체 기업 대상 5

plt.plot(caar[5])
plt.axvline(x=10.5, c='r')
plt.show()

result = stat_test(caar[5])
print(result.summary())
result = stat_test2(caar[5])
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.707
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     20.95
# Date:                Fri, 02 Nov 2018   Prob (F-statistic):           4.12e-07
# Time:                        18:47:19   Log-Likelihood:                 120.45
# No. Observations:                  30   AIC:                            -232.9
# Df Residuals:                      26   BIC:                            -227.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0057      0.003      2.054      0.050   -5.19e-06       0.011
# ...

# %%
## 재벌 기업 대상 0

plt.plot(chaebeol_caar[0])
plt.axvline(x=10.5, c='r')
plt.show()

result = stat_test(chaebeol_caar[0])
print(result.summary())
result = stat_test2(chaebeol_caar[0])
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.777
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     30.23
# Date:                Fri, 02 Nov 2018   Prob (F-statistic):           1.24e-08
# Time:                        18:47:19   Log-Likelihood:                 119.72
# No. Observations:                  30   AIC:                            -231.4
# Df Residuals:                      26   BIC:                            -225.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0106      0.003      3.743      0.001       0.005       0.016
# ...

# %%
## 재벌 기업 대상 1

plt.plot(chaebeol_caar[1])
plt.axvline(x=10.5, c='r')
plt.show()

result = stat_test(chaebeol_caar[1])
print(result.summary())
result = stat_test2(chaebeol_caar[1])
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                 -0.071
# Method:                 Least Squares   F-statistic:                    0.3588
# Date:                Fri, 02 Nov 2018   Prob (F-statistic):              0.783
# Time:                        18:47:19   Log-Likelihood:                 109.75
# No. Observations:                  30   AIC:                            -211.5
# Df Residuals:                      26   BIC:                            -205.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0064      0.004     -1.619      0.118      -0.014       0.002
# ...

# %%
## 재벌 기업 대상 2

plt.plot(chaebeol_caar[2])
plt.axvline(x=10.5, c='r')
plt.show()

result = stat_test(chaebeol_caar[2])
print(result.summary())
result = stat_test2(chaebeol_caar[2])
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.628
# Model:                            OLS   Adj. R-squared:                  0.585
# Method:                 Least Squares   F-statistic:                     14.61
# Date:                Fri, 02 Nov 2018   Prob (F-statistic):           8.96e-06
# Time:                        18:47:20   Log-Likelihood:                 113.90
# No. Observations:                  30   AIC:                            -219.8
# Df Residuals:                      26   BIC:                            -214.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0052      0.003      1.531      0.138      -0.002       0.012
# ...

# %%
## 재벌 기업 대상 3

plt.plot(chaebeol_caar[3])
plt.axvline(x=10.5, c='r')
plt.show()

result = stat_test(chaebeol_caar[3])
print(result.summary())
result = stat_test2(chaebeol_caar[3])
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.891
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     70.94
# Date:                Fri, 02 Nov 2018   Prob (F-statistic):           1.20e-12
# Time:                        18:47:20   Log-Likelihood:                 109.97
# No. Observations:                  30   AIC:                            -211.9
# Df Residuals:                      26   BIC:                            -206.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0061      0.004     -1.567      0.129      -0.014       0.002
# ...

# %%
## 재벌 기업 대상 4

plt.plot(chaebeol_caar[4])
plt.axvline(x=10.5, c='r')
plt.show()

result = stat_test(chaebeol_caar[4])
print(result.summary())
result = stat_test2(chaebeol_caar[4])
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.922
# Method:                 Least Squares   F-statistic:                     115.1
# Date:                Fri, 02 Nov 2018   Prob (F-statistic):           3.93e-15
# Time:                        18:47:20   Log-Likelihood:                 130.60
# No. Observations:                  30   AIC:                            -253.2
# Df Residuals:                      26   BIC:                            -247.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.002      1.371      0.182      -0.001       0.007
# ...

# %%
## 재벌 기업 대상 5

plt.plot(chaebeol_caar[5])
plt.axvline(x=10.5, c='r')
plt.show()

result = stat_test(chaebeol_caar[5])
print(result.summary())
result = stat_test2(chaebeol_caar[5])
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.674
# Model:                            OLS   Adj. R-squared:                  0.637
# Method:                 Least Squares   F-statistic:                     17.93
# Date:                Fri, 02 Nov 2018   Prob (F-statistic):           1.63e-06
# Time:                        18:47:20   Log-Likelihood:                 123.44
# No. Observations:                  30   AIC:                            -238.9
# Df Residuals:                      26   BIC:                            -233.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0017      0.002      0.689      0.497      -0.003       0.007
# ...
